# %% [markdown]
# ## Import common modules

# %%
import pandas as pd
import numpy as np
import nltk
import os
import re
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load web scraped data

# %%
data = pd.read_excel("web_scraping.xlsx")
data.head()
# Out:
#    URL_ID                                                URL  \
# 0      37  https://insights.blackcoffer.com/ai-in-healthc...
# 1      38  https://insights.blackcoffer.com/what-if-the-c...
# 2      39  https://insights.blackcoffer.com/what-jobs-wil...
# 3      40  https://insights.blackcoffer.com/will-machine-...
# 4      41  https://insights.blackcoffer.com/will-ai-repla...
#
#                                              article
# 0  \nAI in healthcare to Improve Patient Outcomes...
# 1  What if the Creation is Taking Over the Creato...
# 2  What Jobs Will Robots Take From Humans in The ...
# 3  Will Machine Replace The Human in the Future o...
# 4  Will AI Replace Us or Work With Us? “Machine i...

# %% [markdown]
# ## Import Stopwords

# %%
stop_word_dir=r"StopWords/"
stop_words=[]
for i in os.listdir(stop_word_dir):
    stop_file=open(stop_word_dir+i,"r")
    temp_list=(stop_file.read()).split('\n')
    for i in temp_list:
        j=i.split(" |")
        stop_words.append(j[0])
    stop_file.close

# %% [markdown]
# ## Imported positive and negative words

# %%
pos_file=open(r"MasterDictionary/positive-words.txt","r")
pos_list=(pos_file.read()).split('\n')
pos_file.close
neg_file=open(r"MasterDictionary/negative-words.txt","r")
neg_list=((neg_file.read()).split('\n'))
neg_file.close
print(len(pos_list),len(neg_list))
# Out:
# 2007 4784

# %% [markdown]
# ## Added new columns for Text Analysis

# %%
column_list=["words","sentences","POSITIVE SCORE","NEGATIVE SCORE","POLARITY SCORE", "SUBJECTIVITY SCORE","AVG SENTENCE LENGTH",
             "PERCENTAGE OF COMPLEX WORDS","FOG INDEX","AVG NUMBER OF WORDS PER SENTENCE","COMPLEX WORD COUNT",
             "WORD COUNT","SYLLABLE PER WORD","PERSONAL PRONOUNS","AVG WORD LENGTH"]
for i in column_list:
    data[i]=np.nan

# %% [markdown]
# ## Tokenize article and remove punctuations

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer=RegexpTokenizer(r'\w+')
for i in range(len(data)):
    if (str(data["article"][i])!="nan"):
        data["words"][i]=tokenizer.tokenize(str(data["article"][i]).lower())

# %% [markdown]
# ## Tokenize article in sentences tokens for future refrences

# %%
from nltk.tokenize import sent_tokenize
for i in range(len(data)):
    if (str(data["article"][i])!="nan"):
        data["sentences"][i]=sent_tokenize(str(data["article"][i]))

# %% [markdown]
# ## Performed word count by removing NLTK stopwords

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
stopwords = stopwords.words('english')
for i in range(len(data)):
    if (str(data["article"][i])!="nan"):
        data["WORD COUNT"][i] = len([words for words in data["words"][i] if not words in stopwords])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Gautam\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Performed multipe operations
#
# ### Extracting Derived variables
# - Positive score
# - Negative score
# - Polarity score
# - Subjective score
#
# ### Analysis of Readability
# - Average sentence length
# - Complex word count
# - Percentage of complex words
# - Fog index
#
# ### Average Number of Words Per Sentence
# - Avg number of words per sentence
#
# ### Syllable Count Per Word
# - Syllable per word
#
# ### Average Word Length
# - Avg word length

# %%
pattern_1="a|e|i|o|u"

for i in range(len(data)):
    if str(data["article"][i])=="nan":
        continue
    pos=0
    neg=0
    complex_words=0
    words_len=0
    total_words=0
    total_syllable=0
    for j in data["words"][i]:
        words_len+=len(j)
        syllable_count = len(re.findall(pattern_1,j))
        if re.search("es$|ed$",j):
            syllable_count-=1
        total_syllable+=syllable_count
        if syllable_count > 2:
            complex_words += 1
        if j not in stop_words:
            total_words+=1
            if j in pos_list:
                pos+=1
            if j in neg_list:
                neg+=1
    
    data["POSITIVE SCORE"][i]=pos
    data["NEGATIVE SCORE"][i]=neg
    data["POLARITY SCORE"][i]=(pos-neg)/(pos+neg+0.000001)
    data["SUBJECTIVITY SCORE"][i]=(pos+neg)/(total_words+0.000001)
    
    data["AVG SENTENCE LENGTH"][i]=len(data.words[i])/len(data.sentences[i])
    data["COMPLEX WORD COUNT"][i]=complex_words
    data["PERCENTAGE OF COMPLEX WORDS"][i]=complex_words*100/len(data.words[i])
    data["FOG INDEX"][i]=0.4*((data["AVG SENTENCE LENGTH"][i])+(data["PERCENTAGE OF COMPLEX WORDS"][i]))
    
    data["AVG NUMBER OF WORDS PER SENTENCE"][i]=len(data.words[i])/len(data.sentences[i])
    
    data["SYLLABLE PER WORD"][i]=total_syllable/len(data.words[i])
        
    data["AVG WORD LENGTH"][i]=words_len/len(data.words[i])

# %% [markdown]
# ## Found the number of Personal Pronouns using regex module

# %%
for i in range(len(data)):
    if str(data["article"][i])!="nan":
        pattern=" I | i | we | We | my | My | ours | Ours | us | Us"
        data["PERSONAL PRONOUNS"][i]=len(re.findall(pattern, str(data["article"][i])))

# %% [markdown]
# ## Viewing our data after all operations

# %%
data.head(10)
# Out:
#    URL_ID                                                URL  \
# 0      37  https://insights.blackcoffer.com/ai-in-healthc...
# 1      38  https://insights.blackcoffer.com/what-if-the-c...
# 2      39  https://insights.blackcoffer.com/what-jobs-wil...
# 3      40  https://insights.blackcoffer.com/will-machine-...
# 4      41  https://insights.blackcoffer.com/will-ai-repla...
# 5      42  https://insights.blackcoffer.com/man-and-machi...
# 6      43  https://insights.blackcoffer.com/in-future-or-...
# 7      44  https://insights.blackcoffer.com/how-neural-ne...
# 8      45  https://insights.blackcoffer.com/how-machine-l...
# 9      46  https://insights.blackcoffer.com/deep-learning...
#
#                                              article  \
# 0  \nAI in healthcare to Improve Patient Outcomes...
# 1  What if the Creation is Taking Over the Creato...
# 2  What Jobs Will Robots Take From Humans in The ...
# 3  Will Machine Replace The Human in the Future o...
# 4  Will AI Replace Us or Work With Us? “Machine i...
# 5  Will machine replace the human in the future o...
# 6  How humans and machines are evolving to work t...
# 7                                                NaN
# 8  How machine learning will affect your business...
# 9  Deep learning impact on areas of e-learning? e...
#
#                                                words  \
# 0  [ai, in, healthcare, to, improve, patient, out...
# 1  [what, if, the, creation, is, taking, over, th...
# 2  [what, jobs, will, robots, take, from, humans,...
# 3  [will, machine, replace, the, human, in, the, ...
# 4  [will, ai, replace, us, or, work, with, us, ma...
# 5  [will, machine, replace, the, human, in, the, ...
# 6  [how, humans, and, machines, are, evolving, to...
# 7                                                NaN
# 8  [how, machine, learning, will, affect, your, b...
# 9  [deep, learning, impact, on, areas, of, e, lea...
#
#                                            sentences  POSITIVE SCORE  \
# 0  [\nAI in healthcare to Improve Patient Outcome...            71.0
# 1  [What if the Creation is Taking Over the Creat...            61.0
# 2  [What Jobs Will Robots Take From Humans in The...            65.0
# 3  [Will Machine Replace The Human in the Future ...            68.0
# 4  [Will AI Replace Us or Work With Us?, “Machine...            62.0
# 5  [Will machine replace the human in the future ...            48.0
# 6  [How humans and machines are evolving to work ...            27.0
# 7                                                NaN             NaN
# 8  [How machine learning will affect your busines...            38.0
# 9  [Deep learning impact on areas of e-learning?,...            69.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            36.0        0.327103            0.102786            24.200000
# 1            37.0        0.244898            0.158833            18.050000
# 2            36.0        0.287129            0.116226            20.105882
# 3            27.0        0.431579            0.133615            17.200000
# 4            25.0        0.425287            0.104946            22.649351
# 5            26.0        0.297297            0.127807            21.245902
# 6            12.0        0.384615            0.109551            16.555556
# 7             NaN             NaN                 NaN                  NaN
# 8            14.0        0.461538            0.153392            20.472222
# 9            45.0        0.210526            0.111111            27.234568
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                    32.011019  22.484408                         24.200000
# 1                    19.598338  15.059335                         18.050000
# 2                    29.783499  19.955753                         20.105882
# 3                    21.297430  15.398972                         17.200000
# 4                    22.133028  17.912951                         22.649351
# 5                    21.527778  17.109472                         21.245902
# 6                    19.194631  14.300075                         16.555556
# 7                          NaN        NaN                               NaN
# 8                    20.217096  16.275727                         20.472222
# 9                    23.300091  20.213863                         27.234568
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0               581.0      1163.0           2.065014                1.0
# 1               283.0       758.0           1.756925                6.0
# 2               509.0       995.0           2.002926                3.0
# 3               348.0       898.0           1.828641               17.0
# 4               386.0       979.0           1.809633               15.0
# 5               279.0       684.0           1.817130               16.0
# 6               143.0       417.0           1.805369                7.0
# 7                 NaN         NaN                NaN                NaN
# 8               149.0       399.0           1.731343                0.0
# 9               514.0      1219.0           1.863554                8.0
#
#    AVG WORD LENGTH
# 0         5.552617
# 1         4.713989
# 2         5.346987
# 3         4.766218
# 4         4.931766
# 5         4.909722
# 6         4.982550
# 7              NaN
# 8         4.691995
# 9         4.806890

# %% [markdown]
# ## Drop the unnecessary columns and save the data

# %%
data.drop(["article", "words","sentences"],axis=1,inplace=True)
data.to_excel("final_output_data.xlsx",index=False)
